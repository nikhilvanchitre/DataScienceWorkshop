# %%
import pandas as pd
pd.set_option("display.max_rows",1000)    # or pd.options.display.max_rows=1000
pd.set_option("display.max_columns",20)   # or pd.options.display.max_columns=20 
pd.set_option('precision',7)
pd.set_option('large_repr', 'truncate')

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.describe()
# Out:
#            ounces
# count   9.0000000
# mean    6.0555556
# std     2.8553069
# min     3.0000000
# 25%     4.0000000
# 50%     6.0000000
# 75%     7.5000000
# max    12.0000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
# group     9 non-null object
# ounces    9 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes

# %%
data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=False)
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.sort_values(by=['group','ounces'], ascending=[False, True], inplace=True)
data
# Out:
#   group  ounces
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 1     a     3.0
# 0     a     4.0
# 2     a    12.0

# %%
import pandas as pd
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, Nik, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-18bce576ccd6> in <module>()
# ----> 1 data.replace(-999, Nik, inplace=True)
#       2 data
#
# NameError: name 'Nik' is not defined

# %%
data.replace(-999, np.Nik, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a40ef94cf13a> in <module>()
# ----> 1 data.replace(-999, np.Nik, inplace=True)
#       2 data
#
# NameError: name 'np' is not defined

# %%
data.replace(-999, np.nan, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9680653b6e3f> in <module>()
# ----> 1 data.replace(-999, np.nan, inplace=True)
#       2 data
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
data.replace(-999, np.nan, inplace=True)
data
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})
df
Out[1]:
# Out:
#   File "<ipython-input-13-4c483ab24d69>", line 8
#     Out[1]:
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})
df
# Out:
#        data1      data2 key1 key2
# 0 -0.0945038  1.2185687    a  one
# 1 -0.3975135 -0.8884550    a  two
# 2  1.6450494  0.1679999    b  one
# 3 -0.6423549 -1.0034631    b  two
# 4 -1.6737832 -0.2334402    a  one

# %%
grouped = df['data1'].groupby(df['key1'])
grouped.mean()
# Out:
# key1
# a   -0.7219335
# b    0.5013472
# Name: data1, dtype: float64

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
import pandas as pd

df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})
df
# Out:
#        data1      data2 key1 key2
# 0 -0.0716122 -0.3305900    a  one
# 1  0.0113301  0.9163808    a  two
# 2 -0.4329907 -0.3079330    b  one
# 3  0.5968264 -0.1846301    b  two
# 4 -2.0604434 -2.4813278    a  one

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.median()
# Out:
# key1
# a   -0.0716122
# b    0.0819179
# Name: data1, dtype: float64

# %%
import numpy as np
np.loadtxt("G:\Python\ml-1m")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-85824841a26a> in <module>()
#       1 import numpy as np
# ----> 2 np.loadtxt("G:\Python\ml-1m")
#
# C:\Users\123\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(bz2.BZ2File(fname))
#     802             elif sys.version_info[0] == 2:
# --> 803                 fh = iter(open(fname, 'U'))
#     804             else:
#     805                 fh = iter(open(fname))
#
# IOError: [Errno 13] Permission denied: 'G:\\Python\\ml-1m'

# %%
import numpy as np
np.loadtxt("G:\Python\ml-1m\movies.dat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5e52c82d3976> in <module>()
#       1 import numpy as np
# ----> 2 np.loadtxt("G:\Python\ml-1m\movies.dat")
#
# C:\Users\123\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Users\123\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import numpy as np
np.loadtxt('G:\Python\ml-1m\movies.dat')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-3fb634de042a> in <module>()
#       1 import numpy as np
# ----> 2 np.loadtxt('G:\Python\ml-1m\movies.dat')
#
# C:\Users\123\Anaconda2\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Users\123\Anaconda2\lib\site-packages\numpy\lib\npyio.py in floatconv(x)
#     657         if b'0x' in x:
#     658             return float.fromhex(asstr(x))
# --> 659         return float(x)
#     660
#     661     typ = dtype.type
#
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat')
df
# Out:
#        1::Toy Story (1995)::Animation|Children's|Comedy
# 0       2::Jumanji (1995)::Adventure|Children's|Fantasy
# 1            3::Grumpier Old Men (1995)::Comedy|Romance
# 2             4::Waiting to Exhale (1995)::Comedy|Drama
# 3         5::Father of the Bride Part II (1995)::Comedy
# 4                 6::Heat (1995)::Action|Crime|Thriller
# 5                     7::Sabrina (1995)::Comedy|Romance
# 6          8::Tom and Huck (1995)::Adventure|Children's
# 7                        9::Sudden Death (1995)::Action
# 8       10::GoldenEye (1995)::Action|Adventure|Thriller
# 9     11::American President, The (1995)::Comedy|Dra...
# 10    12::Dracula: Dead and Loving It (1995)::Comedy...
# 11               13::Balto (1995)::Animation|Children's
# 12                              14::Nixon (1995)::Drama
# 13    15::Cutthroat Island (1995)::Action|Adventure|...
# 14                    16::Casino (1995)::Drama|Thriller
# 15      17::Sense and Sensibility (1995)::Drama|Romance
# ...

# %%
import pandas as pd
with open('G:\Python\ml-1m\movies.dat') as m:
    table = pd.read_table(m, sep='::', index_col=0, header=None, names=['MovieID','Title','Genre'],
                          lineterminator='\n')
    table
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::')
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#          1                                   Toy Story (1995)  \
# 0        2                                     Jumanji (1995)
# 1        3                            Grumpier Old Men (1995)
# 2        4                           Waiting to Exhale (1995)
# 3        5                 Father of the Bride Part II (1995)
# 4        6                                        Heat (1995)
# 5        7                                     Sabrina (1995)
# 6        8                                Tom and Huck (1995)
# 7        9                                Sudden Death (1995)
# 8       10                                   GoldenEye (1995)
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::',index_col=0, header=None, names=['MovieId','Name','Genre'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#                                                       Name  \
# MovieId
# 1                                         Toy Story (1995)
# 2                                           Jumanji (1995)
# 3                                  Grumpier Old Men (1995)
# 4                                 Waiting to Exhale (1995)
# 5                       Father of the Bride Part II (1995)
# 6                                              Heat (1995)
# 7                                           Sabrina (1995)
# 8                                      Tom and Huck (1995)
# 9                                      Sudden Death (1995)
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::',index_col=1, header=None, names=['MovieId','Name','Genre'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#                                                     MovieId  \
# Name
# Toy Story (1995)                                          1
# Jumanji (1995)                                            2
# Grumpier Old Men (1995)                                   3
# Waiting to Exhale (1995)                                  4
# Father of the Bride Part II (1995)                        5
# Heat (1995)                                               6
# Sabrina (1995)                                            7
# Tom and Huck (1995)                                       8
# Sudden Death (1995)                                       9
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::',index_col=0, header=None, names=['MovieId','Name','Genre'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#                                                       Name  \
# MovieId
# 1                                         Toy Story (1995)
# 2                                           Jumanji (1995)
# 3                                  Grumpier Old Men (1995)
# 4                                 Waiting to Exhale (1995)
# 5                       Father of the Bride Part II (1995)
# 6                                              Heat (1995)
# 7                                           Sabrina (1995)
# 8                                      Tom and Huck (1995)
# 9                                      Sudden Death (1995)
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::',index_col=0, header=None, names=['MovieId','Name','Genre'],lineterminator='\n')
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#                                                       Name  \
# MovieId
# 1                                         Toy Story (1995)
# 2                                           Jumanji (1995)
# 3                                  Grumpier Old Men (1995)
# 4                                 Waiting to Exhale (1995)
# 5                       Father of the Bride Part II (1995)
# 6                                              Heat (1995)
# 7                                           Sabrina (1995)
# 8                                      Tom and Huck (1995)
# 9                                      Sudden Death (1995)
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::', header=None, names=['MovieId','Name','Genre'],lineterminator='\n')
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#       MovieId                                               Name  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# ...

# %%
import pandas as pd
nc = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::',index_col=0, header=None, names=['UserId','MovieId','Ratings','Timestamp'],lineterminator='\n')
nc
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-33-620a84e5a0d4> in <module>()
#       1 import pandas as pd
# ----> 2 nc = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::',index_col=0, header=None, names=['UserId','MovieId','Ratings','Timestamp'],lineterminator='\n')
#       3 nc
#
# ...

# %%
import pandas as pd
ra = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
ra
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-ad6d76cd2738> in <module>()
#       1 import pandas as pd
# ----> 2 ra = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
#       3 ra
#
# ...

# %%
import pandas as pd
ra = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
ra
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-35-ad6d76cd2738> in <module>()
#       1 import pandas as pd
# ----> 2 ra = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
#       3 ra
#
# ...

# %%
import pandas as pd
ra = pd.read_table('ml-1m\ratings.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
ra
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-36-44a32d09f252> in <module>()
#       1 import pandas as pd
# ----> 2 ra = pd.read_table('ml-1m\ratings.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
#       3 ra
#
# ...

# %%
import pandas as pd
ra = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
ra
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-57b55ebb9214> in <module>()
#       1 import pandas as pd
# ----> 2 ra = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
#       3 ra
#
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-d35bd6e34ba4> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::', header=None, names=['UserID','MovieId','Ratings','Timestamp'],lineterminator='\n')
#       3 df
#
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep='::',index_col=0, header=None, names=['MovieId','Name','Genre'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#                                                       Name  \
# MovieId
# 1                                         Toy Story (1995)
# 2                                           Jumanji (1995)
# 3                                  Grumpier Old Men (1995)
# 4                                 Waiting to Exhale (1995)
# 5                       Father of the Bride Part II (1995)
# 6                                              Heat (1995)
# 7                                           Sabrina (1995)
# 8                                      Tom and Huck (1995)
# 9                                      Sudden Death (1995)
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\movies.dat', sep = '::',index_col=0, header=None, names=['MovieId','Name','Genre'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#                                                       Name  \
# MovieId
# 1                                         Toy Story (1995)
# 2                                           Jumanji (1995)
# 3                                  Grumpier Old Men (1995)
# 4                                 Waiting to Exhale (1995)
# 5                       Father of the Bride Part II (1995)
# 6                                              Heat (1995)
# 7                                           Sabrina (1995)
# 8                                      Tom and Huck (1995)
# 9                                      Sudden Death (1995)
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\users.dat', sep='::',index_col=0, header=None, names=['UserID','Gender','Age','Occupation','Zip_code'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#        Gender  Age  Occupation    Zip_code
# UserID
# 1           F    1          10       48067
# 2           M   56          16       70072
# 3           M   25          15       55117
# 4           M   45           7       02460
# 5           M   25          20       55455
# 6           F   50           9       55117
# 7           M   35           1       06810
# 8           M   25          12       11413
# 9           M   25          17       61614
# 10          F   35           1       95370
# 11          F   25           1       04093
# 12          M   25          12       32793
# 13          M   45           1       93304
# ...

# %%
import pandas as pd
df = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::',index_col=0, header=None, names=['UserID','MovieID','Ratings','Timestamp'])
df
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-42-f808536abd8f> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_table('G:\Python\ml-1m\ratings.dat', sep='::',index_col=0, header=None, names=['UserID','MovieID','Ratings','Timestamp'])
#       3 df
#
# ...

# %%
pd.read_csv("G:\Python\ml-1m\ratings.dat",sep ="::")
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-43-7da345a291b9> in <module>()
# ----> 1 pd.read_csv("G:\Python\ml-1m\ratings.dat",sep ="::")
#
# ...

# %%
pd.read_csv("G:\Python\ml-1m\ratings.dat",sep ="::")
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-44-7da345a291b9> in <module>()
# ----> 1 pd.read_csv("G:\Python\ml-1m\ratings.dat",sep ="::")
#
# ...

# %%
pd.read_csv("C:\Users\123\Anaconda2\ml-1m\Ratings.dat",sep ="::")
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-45-63874be48d13> in <module>()
# ----> 1 pd.read_csv("C:\Users\123\Anaconda2\ml-1m\Ratings.dat",sep ="::")
#
# ...

# %%
pd.read_csv("G:\Python\ml-1m\Rat.dat",sep ="::")
# Out:
# C:\Users\123\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
#             1  1193  5  978300760
# 0           1   661  3  978302109
# 1           1   914  3  978301968
# 2           1  3408  4  978300275
# 3           1  2355  5  978824291
# 4           1  1197  3  978302268
# 5           1  1287  5  978302039
# 6           1  2804  5  978300719
# 7           1   594  4  978302268
# 8           1   919  4  978301368
# 9           1   595  5  978824268
# 10          1   938  4  978301752
# 11          1  2398  4  978302281
# 12          1  2918  4  978302124
# 13          1  1035  5  978301753
# 14          1  2791  4  978302188
# 15          1  2687  3  978824268
# 16          1  2018  4  978301777
# ...
